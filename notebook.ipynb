# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# 1. Install specific requirements
# !pip install -r third_party/DeltaVLM/requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'third_party/DeltaVLM/requirements.txt'

# %%
# !pip install transformers==4.33.2 peft

# %%
# !pwd
# Out:
# /kaggle/working

# %%
# !ls -la /kaggle/working
# Out:
# total 12
# drwxr-xr-x 3 root root 4096 Sep  8 15:12 .
# drwxr-xr-x 5 root root 4096 Sep  8 15:12 ..
# drwxr-xr-x 2 root root 4096 Sep  8 15:12 .virtual_documents

# %%
# !find /kaggle -path "*/third_party/DeltaVLM/requirements.txt" 2>/dev/null
