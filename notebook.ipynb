# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
from kaggle_secrets import UserSecretsClient
secrets = UserSecretsClient()
token = secrets.get_secret("GITHUB_TOKEN")

# %%
# !git clone https://Vaishnavi1dev:{token}@github.com/Vaishnavi1dev/satquery.git
# Out:
# Cloning into 'satquery'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 59 (delta 0), reused 59 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (59/59), 62.79 KiB | 3.30 MiB/s, done.

# %%
# !pwd
# Out:
# /kaggle/working

# %%
# !ls
# Out:
# satquery

# %%
# !mkdir /kaggle/working/satquery/third_party
# %cd /kaggle/working/satquery/third_party
# !git clone https://github.com/hiyamdebary/EarthDial.git EarthDial
# Out:
# /kaggle/working/satquery/third_party
# Cloning into 'EarthDial'...
# remote: Enumerating objects: 256, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 256 (delta 10), reused 13 (delta 5), pack-reused 227 (from 1)
# Receiving objects: 100% (256/256), 65.95 MiB | 51.51 MiB/s, done.
# Resolving deltas: 100% (80/80), done.

# %%
# %cd /kaggle/working/satquery/third_party
# !git clone https://github.com/zhu-xlab/DOFA.git DOFA
# Out:
# /kaggle/working/satquery/third_party
# Cloning into 'DOFA'...
# remote: Enumerating objects: 33257, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 33257 (delta 106), reused 111 (delta 71), pack-reused 33088 (from 3)
# Receiving objects: 100% (33257/33257), 1.00 GiB | 41.07 MiB/s, done.
# Resolving deltas: 100% (773/773), done.

# %%
# !git clone https://github.com/hiyamdebary/EarthDial.git Earthdial
# Out:
# Cloning into 'Earthdial'...
# remote: Enumerating objects: 597, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 597 (delta 43), reused 36 (delta 36), pack-reused 550 (from 1)
# Receiving objects: 100% (597/597), 8.44 MiB | 14.83 MiB/s, done.
# Resolving deltas: 100% (285/285), done.

# %%
# !pip install peft transformers timm torchgeo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.4/811.4 kB 13.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.8/174.8 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 891.2/891.2 kB 33.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 27.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.1/163.1 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 62.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.2/800.2 kB 30.0 MB/s eta 0:00:00
# ...
